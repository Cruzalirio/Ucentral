# %% [markdown]
# # Fundamentos de estadística para Analítica de Datos
#
# Basado en [este documento](https://www.ine.es/explica/docs/historia_estadistica.pdf)
#
# 1. La palabra Estadística tiene dos acepciones en general, por un lado es el hecho de estudiar las características de una población y sus integrantes; y por otro lado es una disciplina científica que entre muchas otras utilidades puede usarse para deducir relaciones entre variables, o para extender los resultados que obtengamos para una parte de la población a toda la población.
# 2. Estadística significa ciencia del Estado, y proviene del término alemán Statistik. ¿Por qué la ciencia del Estado? Porque en sus orígenes la estadística se utilizaba exclusivamente con fines estatales, en el sentido de que los gobiernos de las distintas naciones tenían (y tienen) la necesidad, por razones de organización, de conocer las características de su población para gestionar el pago de impuestos, el reclutamiento de soldados, el reparto de tierras o bienes, la prestación de servicios públicos etc.
# 3. Esta necesidad llevó a los gobernantes a establecer sistemas para recoger y procesar de alguna manera la información obtenida, es decir, a hacer estadísticas sobre la población.

# %% [markdown]
# ## Historia de la estadística
#
# 1. Censo de Israel en Sinaí, vamos a leer [acá](https://www.biblegateway.com/passage/?search=N%C3%BAmeros%201&version=RVR1960)
# 2. En China, en el año 2238 a.C. el emperador Yao manda elaborar un censo general que recogió datos sobre la actividad agrícola, industrial y comercial.
# 3. En la antigua Grecia también se realizaron censos para cuantificar la distribución y posesión de la tierra y otras riquezas, organizar el servicio militar y determinar el derecho a voto de los ciudadanos. (Ver el video de que es la [democracia](https://www.youtube.com/watch?v=0fivQUlC7-8)
# 4. Los censos y la actividad estadística tuvieron especial importancia en la antigua Roma. Durante el Imperio Romano se establecieron registros de nacimientos y defunciones, y se elaboraron estudios sobre los ciudadanos del Imperio, sus tierras y riquezas. El rey romano Servio Tulio (578 – 535 a.C.) elaboró un catastro de todos los dominios de Roma
#
# 5. En Inglaterra la epidemia de peste de la década de 1500 provoca que comiencen a publicarse semanalmente datos sobre defunciones (Bills of Mortality). Con el tiempo a estos datos de mortalidad se le añadieron datos de nacimientos por sexo.
# 6. El comerciante inglés John Graunt está considerado uno de los fundadores de la estadística moderna. En su obra Natural and political observations (1662) realiza un análisis de los datos recogidos en las tablas de mortalidad anteriores; por ejemplo hace predicciones sobre los fallecimientos y nacimientos que cabría esperar en el futuro.
#
# 7. Matemáticos como Pascal y Fermat sentaron las bases de la Teoría de la Probabilidad, utilizada para estudiar fenómenos aleatorios (aquellos que pueden tener varios resultados y en los que la aparición de un resultado particular no puede predecirse, por ejemplo el lanzamiento de un dado) que luego comenzó a aplicarse a sucesos demográficos y económicos, puesto que muchos de ellos se comportan como fenómenos aleatorios
#
# 8. Los trabajo de científicos como Laplace, Gauss y Legendre desarrollaron dos conceptos muy usados en el análisis estadístico: la teoría sobre los errores en la observación, y el método de los mínimos cuadrados. De las investigaciones de Galton y Pearson surgieron los conceptos de correlación y curva de regresión, también muy utilizados hoy día.

# %% [markdown]
# ## Estadistica Descriptiva
#
# Tomado de [acá](https://economipedia.com/definiciones/estadistica-descriptiva.html)
#
# 1. La estadística descriptiva trata de describir algo. Pero no describirlo de cualquiera forma, sino de manera cuantitativa. Pensemos en el peso de una caja de verduras, en la altura de una persona o en la cantidad de dinero que gana una empresa. De estas variables podríamos decir muchas cosas. Por ejemplo, podríamos indicar que esta o aquella caja de tomates pesan mucho o pesan menos que otras. Siguiendo con otro ejemplo, podríamos decir que el ingreso de una empresa varía mucho a lo largo del tiempo o que una persona tiene una altura promedio.
#
# 2. Para dictar las afirmaciones anteriores, sobre mucho, poco, alto, bajo, muy variable o poco variable necesitamos variables de medidas. Esto es, necesitamos cuantificarlas, ofrecer un número. Con esto en mente, podríamos utilizar los gramos o los kilogramos como unidad de medida para saber el peso de tantas cajas de tomates como consideremos. Una vez pesemos treinta cajas, sabremos cuales pesan más, cuales pesan menos, que cuantía es la que más se repite o si existe mucha disparidad entre los pesos de las diferentes cajas.
#
# 3. Con esta idea nace la estadística descriptiva, con la de recoger datos, almacenarlos, realizar tablas o incluso gráficos que nos ofrezcan información sobre un determinado asunto. Adicionalmente, nos ofrecen medidas que resumen la información de una gran cantidad de datos.

# %% [markdown]
# # Estadística Univariada
# El objetivo de esta sección es conocer las formas de resumir la información en tablas y gráficos.
#
# Vamos a trabajar en Python.

# %%
## Pandas datafrmaes y variables
import pandas as pd
## Numerical Python
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Carga de datos
#
# Primero vamos a cargar la hoja de datos de la prueba [SABER 11](https://www.datos.gov.co/Educaci-n/Saber-11-2019-2/ynam-yc42 ) del año 2019.

# %%
datos = pd.read_csv("/content/drive/MyDrive/2023/Fundamentos de Estadistica/Hojas de datos/Saber_11__2019-2.csv", na_values="-")
datos
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                      TI          COLOMBIA           M
# 1                      TI          COLOMBIA           M
# 2                      TI          COLOMBIA           M
# 3                      TI          COLOMBIA           M
# 4                      TI          COLOMBIA           M
# ...                   ...               ...         ...
# 546207                 CC          COLOMBIA           M
# 546208                 TI          COLOMBIA           M
# 546209                 TI          COLOMBIA           M
# 546210                 TI          COLOMBIA           M
# 546211                 TI          COLOMBIA           M
#
#           ESTU_FECHANACIMIENTO  PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE  \
# 0       02/18/2002 12:00:00 AM    20194  SB11201940031558      ESTUDIANTE
# 1       06/28/2003 12:00:00 AM    20194  SB11201940303339      ESTUDIANTE
# ...

# %%
datos = pd.read_csv("/content/drive/MyDrive/2023/Fundamentos de Estadistica/Hojas de datos/Saber_11__2019-2.csv", na_values="-", index_col=5)
datos
# Out:
#                  ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# ESTU_CONSECUTIVO
# SB11201940031558                 TI          COLOMBIA           M
# SB11201940303339                 TI          COLOMBIA           M
# SB11201940255017                 TI          COLOMBIA           M
# SB11201940154799                 TI          COLOMBIA           M
# SB11201940280831                 TI          COLOMBIA           M
# ...                             ...               ...         ...
# SB11201940195862                 CC          COLOMBIA           M
# SB11201940253002                 TI          COLOMBIA           M
# SB11201940364767                 TI          COLOMBIA           M
# SB11201940210026                 TI          COLOMBIA           M
# SB11201940074679                 TI          COLOMBIA           M
#
#                     ESTU_FECHANACIMIENTO  PERIODO ESTU_ESTUDIANTE  \
# ESTU_CONSECUTIVO
# SB11201940031558  02/18/2002 12:00:00 AM    20194      ESTUDIANTE
# ...

# %% [markdown]
# # Clasificación de variables
# 1. ¿Qué es una variable?:
# 2. ¿Qué es la población?
# 3. ¿Qué es una muestra?
# 4. ¿Qué es un individuo?
#
# ![rsc-42408-5e4eec2f99cf3.png](data:image/png;base64,...)

# %% [markdown]
# ## Definiciones
#
# **Variable**: Una variable estadística es una característica de una muestra o población de datos que puede adoptar diferentes valores.
#
# Aunque hay muchos de tipos de variables estadísticas, por regla general podemos encontrarnos dos tipos de variables:
#
# 1. **Variable cuantitativa**: Son variables que se expresan numéricamente.
# *  a) Variable continua: Toman un valor infinito de valores entre un intervalo de datos.
# *  b) Variable discreta: Toman un valor finito de valores entre un intervalo de datos.
# 2. **Variable cualitativa**: Son variables que se expresan en palabras o en codigos númericos.
# * a) Variable ordinal: Expresa diferentes niveles y orden. Cualquier variable de escala likert. Leer este blog: [¿Qué es la escala lickert?](https://www.questionpro.com/blog/es/que-es-la-escala-de-likert-y-como-utilizarla/)
#
# * b) Variable nominal: Expresa un nombre claramente diferenciado.

# %%
datos.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_ESTUDIANTE', 'ESTU_TIENEETNIA',
#        'ESTU_PAIS_RESIDE', 'ESTU_ETNIA', 'ESTU_DEPTO_RESIDE',
#        'ESTU_COD_RESIDE_DEPTO', 'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR', 'FAMI_CUARTOSHOGAR',
#        'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV',
#        'FAMI_TIENECOMPUTADOR', 'FAMI_TIENELAVADORA',
#        'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
#        'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS',
#        'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
# ...

# %% [markdown]
# ## Tipo de los datos para python

# %%
datos.index
# Out:
# Index(['SB11201940031558', 'SB11201940303339', 'SB11201940255017',
#        'SB11201940154799', 'SB11201940280831', 'SB11201940212273',
#        'SB11201940220718', 'SB11201940334295', 'SB11201940200325',
#        'SB11201940059113',
#        ...
#        'SB11201940056845', 'SB11201940195987', 'SB11201940055934',
#        'SB11201940384638', 'SB11201940099826', 'SB11201940195862',
#        'SB11201940253002', 'SB11201940364767', 'SB11201940210026',
#        'SB11201940074679'],
#       dtype='object', name='ESTU_CONSECUTIVO', length=546212)

# %%
## De que tipo es cada columna
datos.dtypes
# Out:
# ESTU_TIPODOCUMENTO           object
# ESTU_NACIONALIDAD            object
# ESTU_GENERO                  object
# ESTU_FECHANACIMIENTO         object
# PERIODO                       int64
#                              ...
# ESTU_INSE_INDIVIDUAL        float64
# ESTU_NSE_INDIVIDUAL         float64
# ESTU_NSE_ESTABLECIMIENTO    float64
# ESTU_ESTADOINVESTIGACION     object
# ESTU_GENERACION-E            object
# Length: 81, dtype: object

# %%
## las primeras 10 posiciones
datos.dtypes[40:80]
# Out:
# COLE_GENERO                       object
# COLE_NATURALEZA                   object
# COLE_CALENDARIO                   object
# COLE_BILINGUE                     object
# COLE_CARACTER                     object
# COLE_COD_DANE_SEDE                 int64
# COLE_NOMBRE_SEDE                  object
# COLE_SEDE_PRINCIPAL               object
# COLE_AREA_UBICACION               object
# COLE_JORNADA                      object
# COLE_COD_MCPIO_UBICACION           int64
# COLE_MCPIO_UBICACION              object
# COLE_COD_DEPTO_UBICACION           int64
# COLE_DEPTO_UBICACION              object
# ESTU_PRIVADO_LIBERTAD             object
# ESTU_COD_MCPIO_PRESENTACION        int64
# ESTU_MCPIO_PRESENTACION           object
# ESTU_DEPTO_PRESENTACION           object
# ESTU_COD_DEPTO_PRESENTACION        int64
# PUNT_LECTURA_CRITICA               int64
# PERCENTIL_LECTURA_CRITICA          int64
# DESEMP_LECTURA_CRITICA             int64
# PUNT_MATEMATICAS                   int64
# ...

# %%
datos["ESTU_FECHANACIMIENTO"]
# Out:
# ESTU_CONSECUTIVO
# SB11201940031558    02/18/2002 12:00:00 AM
# SB11201940303339    06/28/2003 12:00:00 AM
# SB11201940255017    06/02/2001 12:00:00 AM
# SB11201940154799    04/26/2002 12:00:00 AM
# SB11201940280831    02/05/2002 12:00:00 AM
#                              ...
# SB11201940195862    02/25/1999 12:00:00 AM
# SB11201940253002    10/14/2002 12:00:00 AM
# SB11201940364767    11/22/2002 12:00:00 AM
# SB11201940210026    11/10/2002 12:00:00 AM
# SB11201940074679    06/02/2002 12:00:00 AM
# Name: ESTU_FECHANACIMIENTO, Length: 546212, dtype: object

# %% [markdown]
# ## Primera tarea

# %% [markdown]
# ## Tablas de frecuencias
#
# 1. La tabla de frecuencias es una tabla donde los datos estadísticos aparecen bien organizados, distribuidos según su frecuencia, es decir, según las veces que se repite en la muestra.  En esta tabla se representan los diferentes tipos de frecuencias, ordenados en columnas.  La tabla de frecuencias es una herramienta que permite la realización de las gráficas o diagramas estadísticos de una forma más fácil.
# 2.  La frecuencia absoluta es el número de veces que un dato se repite dentro de un conjunto de datos. Se representa como  donde la  corresponde al número de dato.
# 3. La frecuencia relativa de un dato es el número que se repite ese dato en relación al número total de datos, o en otras palabras, es la proporción de veces que aparece ese dato con respecto al total.
# 4. La frecuencia absoluta acumulada es la suma de las frecuencias absolutas que se va acumulando hasta ese dato, es decir, la frecuencia absoluta acumulada de un dato en concreto se obtiene sumando su frecuencia absoluta a las frecuencias absolutas de los datos que son menores que él.
# 5. La frecuencia relativa acumulada es el mismo concepto que para la frecuencia absoluta acumulada.

# %%
# Cómo lo hacemos en Python
# Tabla de frecuencias aboslutas de la educación del padre

datos.groupby(by="FAMI_EDUCACIONPADRE").size()
# Out:
# FAMI_EDUCACIONPADRE
# Educación profesional completa           46404
# Educación profesional incompleta         10150
# Ninguno                                  20106
# No Aplica                                 6849
# No sabe                                  32104
# Postgrado                                 9437
# Primaria completa                        54141
# Primaria incompleta                     101387
# Secundaria (Bachillerato) completa      117488
# Secundaria (Bachillerato) incompleta     71295
# Técnica o tecnológica completa           35367
# Técnica o tecnológica incompleta         10957
# dtype: int64

# %%
datos["FAMI_EDUCACIONPADRE"].value_counts()
# Out:
# Secundaria (Bachillerato) completa      117488
# Primaria incompleta                     101387
# Secundaria (Bachillerato) incompleta     71295
# Primaria completa                        54141
# Educación profesional completa           46404
# Técnica o tecnológica completa           35367
# No sabe                                  32104
# Ninguno                                  20106
# Técnica o tecnológica incompleta         10957
# Educación profesional incompleta         10150
# Postgrado                                 9437
# No Aplica                                 6849
# Name: FAMI_EDUCACIONPADRE, dtype: int64

# %%
datos['PERCENTIL_MATEMATICAS'].value_counts()
# Out:
# 1     5823
# 2     5736
# 3     5704
# 4     5695
# 8     5643
#       ...
# 91    5383
# 75    5383
# 98    5383
# 74    5381
# 95    5380
# Name: PERCENTIL_MATEMATICAS, Length: 100, dtype: int64

# %% [markdown]
# ## Medidas descriptivas
#
# Valores que resumen una variable, sirven para variables de tipo cuantitativo.

# %%
### Le saca promedio y demás a todo lo que sea numero
###
datos.describe()
# Out:
#         PERIODO  ESTU_COD_RESIDE_DEPTO  ESTU_COD_RESIDE_MCPIO  \
# count  546212.0          545835.000000          545835.000000
# mean    20194.0              57.025856           32739.615413
# std         0.0            1566.335590           26397.937526
# min     20194.0               5.000000            5001.000000
# 25%     20194.0              11.000000           11001.000000
# 50%     20194.0              20.000000           20570.000000
# 75%     20194.0              54.000000           54001.000000
# max     20194.0           99999.000000           99999.000000
#
#        COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# count      546212.000000                   5.462120e+05        5.462120e+05
# mean       197397.840712                   2.038424e+11        2.044208e+11
# std        229636.502160                   9.221826e+10        9.302404e+10
# min            75.000000                   1.050010e+11        1.050010e+11
# ...

# %%
### La lista de valores (pd.Serie), esto no es un dataframe
datos['PUNT_INGLES']
# Out:
# ESTU_CONSECUTIVO
# SB11201940031558    54.0
# SB11201940303339    63.0
# SB11201940255017    64.0
# SB11201940154799    53.0
# SB11201940280831    52.0
#                     ...
# SB11201940195862    58.0
# SB11201940253002    74.0
# SB11201940364767    72.0
# SB11201940210026    46.0
# SB11201940074679    74.0
# Name: PUNT_INGLES, Length: 546212, dtype: float64

# %%
### Esto si es un dataframe
datos[["PUNT_INGLES", "PUNT_MATEMATICAS", "PUNT_C_NATURALES"]].describe()
# Out:
#          PUNT_INGLES  PUNT_MATEMATICAS  PUNT_C_NATURALES
# count  546193.000000     546212.000000     546212.000000
# mean       48.416891         50.606349         48.234779
# std        12.558438         11.997649         10.764035
# min         0.000000          0.000000          0.000000
# 25%        39.000000         42.000000         40.000000
# 50%        48.000000         51.000000         48.000000
# 75%        56.000000         59.000000         56.000000
# max       100.000000        100.000000        100.000000

# %% [markdown]
# ## Boxplot

# %%
###  El grafico de boxplot
figura = px.box(datos, x="PUNT_INGLES")
figura.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
### Borra los NAS
figura = px.box(datos[["PUNT_INGLES", "ESTU_GENERO"]].dropna(), y="PUNT_INGLES", color ="ESTU_GENERO")
figura.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
### Borra los NAS
figura = px.box(datos[["PUNT_INGLES", "FAMI_ESTRATOVIVIENDA"]].dropna(), y="PUNT_INGLES", color ="FAMI_ESTRATOVIVIENDA")
figura.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Cada boxplot se realiza de manera independiente.

# %%
datos[["PUNT_INGLES", "FAMI_ESTRATOVIVIENDA"]].groupby("FAMI_ESTRATOVIVIENDA").median()
# Out:
#                       PUNT_INGLES
# FAMI_ESTRATOVIVIENDA
# Estrato 1                    44.0
# Estrato 2                    49.0
# Estrato 3                    54.0
# Estrato 4                    58.0
# Estrato 5                    57.0
# Estrato 6                    50.0
# Sin Estrato                  38.0

# %%
datos.groupby( "FAMI_ESTRATOVIVIENDA").size()
# Out:
# FAMI_ESTRATOVIVIENDA
# Estrato 1      159977
# Estrato 2      188314
# Estrato 3      108692
# Estrato 4       25810
# Estrato 5        8024
# Estrato 6        3711
# Sin Estrato     17177
# dtype: int64

# %% [markdown]
# Sí solo miramos el estrato 6

# %%
## Seleccionar solo los estrato 6
datos[["PUNT_INGLES", "FAMI_ESTRATOVIVIENDA"]][datos["FAMI_ESTRATOVIVIENDA"]=="Estrato 6"].describe()
# Out:
#        PUNT_INGLES
# count  3711.000000
# mean     52.967125
# std      19.275377
# min       0.000000
# 25%      36.000000
# 50%      50.000000
# 75%      70.000000
# max     100.000000

# %% [markdown]
# ## Tabla de frecuencias
#
# Es una tabla que tiene los conteos por categoria de la variable analizada

# %% [markdown]
# ### Variable Categorica

# %%
## La tabla de fecuencias del servicio de TV
datos.groupby('FAMI_TIENESERVICIOTV', dropna=False).size()

## Se podrían reemplazar por sin información
# Out:
# FAMI_TIENESERVICIOTV
# No     122866
# Si     391419
# NaN     31927
# dtype: int64

# %% [markdown]
# datos[['FAMI_TIENESERVICIOTV']]
#
# .fillna(value="Sin información")
#
# .groupby('FAMI_TIENESERVICIOTV', dropna=False)
#
# .size()

# %%
### Reemplazar los datos de FAMI_TIENESERVICIOTV que son faltantes
### Por la categoría "sin información"
tablaTVConteo = datos[['FAMI_TIENESERVICIOTV']].fillna(value="Sin información").groupby('FAMI_TIENESERVICIOTV', dropna=False).size()
tablaTVConteo
# Out:
# FAMI_TIENESERVICIOTV
# No                 122866
# Si                 391419
# Sin información     31927
# dtype: int64

# %%
tablaTV = datos.groupby('FAMI_TIENESERVICIOTV', dropna=False).mean()

# %%
## La familia si tiene o no TV se volvió el indice
tablaTV
# Out:
#                       PERIODO  ESTU_COD_RESIDE_DEPTO  ESTU_COD_RESIDE_MCPIO  \
# FAMI_TIENESERVICIOTV
# No                    20194.0              50.373940           35202.385785
# Si                    20194.0              58.130730           31792.916864
# NaN                   20194.0              69.074483           34871.658088
#
#                       COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  \
# FAMI_TIENESERVICIOTV
# No                        207574.734646                   1.965288e+11
# Si                        193201.001109                   2.056362e+11
# NaN                       209686.139349                   2.099961e+11
#
#                       COLE_COD_DANE_SEDE  COLE_COD_MCPIO_UBICACION  \
# FAMI_TIENESERVICIOTV
# No                          1.975732e+11              35184.726092
# Si                          2.060582e+11              31821.820001
# NaN                         2.106991e+11              34857.249131
#
# ...

# %%
###  FAMI TIENE SERVICIO TV
tablaTV = datos.groupby('FAMI_TIENESERVICIOTV', dropna=False, as_index=False).mean()
tablaTV
# Out:
#   FAMI_TIENESERVICIOTV  PERIODO  ESTU_COD_RESIDE_DEPTO  ESTU_COD_RESIDE_MCPIO  \
# 0                   No  20194.0              50.373940           35202.385785
# 1                   Si  20194.0              58.130730           31792.916864
# 2                  NaN  20194.0              69.074483           34871.658088
#
#    COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# 0      207574.734646                   1.965288e+11        1.975732e+11
# 1      193201.001109                   2.056362e+11        2.060582e+11
# 2      209686.139349                   2.099961e+11        2.106991e+11
#
#    COLE_COD_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION  \
# 0              35184.726092                 34.893925
# 1              31821.820001                 31.599383
# 2              34857.249131                 34.612115
#
#    ESTU_COD_MCPIO_PRESENTACION  ...  PUNT_SOCIALES_CIUDADANAS  \
# 0                 35208.459859  ...                 44.154787
# ...

# %%
tablaTV[["PUNT_SOCIALES_CIUDADANAS", "PERCENTIL_SOCIALES_CIUDADANAS"]]
# Out:
#                       PUNT_SOCIALES_CIUDADANAS  PERCENTIL_SOCIALES_CIUDADANAS
# FAMI_TIENESERVICIOTV
# No                                   44.154787                      45.270237
# Si                                   47.232804                      52.576308
# NaN                                  41.829361                      39.690137

# %%
tablaTV.columns
# Out:
# Index(['PERIODO', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO',
#        'COLE_CODIGO_ICFES', 'COLE_COD_DANE_ESTABLECIMIENTO',
#        'COLE_COD_DANE_SEDE', 'COLE_COD_MCPIO_UBICACION',
#        'COLE_COD_DEPTO_UBICACION', 'ESTU_COD_MCPIO_PRESENTACION',
#        'ESTU_COD_DEPTO_PRESENTACION', 'PUNT_LECTURA_CRITICA',
#        'PERCENTIL_LECTURA_CRITICA', 'DESEMP_LECTURA_CRITICA',
#        'PUNT_MATEMATICAS', 'PERCENTIL_MATEMATICAS', 'DESEMP_MATEMATICAS',
#        'PUNT_C_NATURALES', 'PERCENTIL_C_NATURALES', 'DESEMP_C_NATURALES',
#        'PUNT_SOCIALES_CIUDADANAS', 'PERCENTIL_SOCIALES_CIUDADANAS',
#        'DESEMP_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PERCENTIL_INGLES',
#        'PUNT_GLOBAL', 'PERCENTIL_GLOBAL', 'ESTU_INSE_INDIVIDUAL',
#        'ESTU_NSE_INDIVIDUAL', 'ESTU_NSE_ESTABLECIMIENTO'],
#       dtype='object')

# %%
importan = [ 'PUNT_LECTURA_CRITICA',
       'PERCENTIL_LECTURA_CRITICA', 'DESEMP_LECTURA_CRITICA',
       'PUNT_MATEMATICAS', 'PERCENTIL_MATEMATICAS', 'DESEMP_MATEMATICAS',
       'PUNT_C_NATURALES', 'PERCENTIL_C_NATURALES', 'DESEMP_C_NATURALES',
       'PUNT_SOCIALES_CIUDADANAS', 'PERCENTIL_SOCIALES_CIUDADANAS',
       'DESEMP_SOCIALES_CIUDADANAS', 'PUNT_INGLES', 'PERCENTIL_INGLES',
       'PUNT_GLOBAL', 'PERCENTIL_GLOBAL', 'ESTU_INSE_INDIVIDUAL',
       'ESTU_NSE_INDIVIDUAL', 'ESTU_NSE_ESTABLECIMIENTO']
tablaTV[importan]
# Out:
#                       PUNT_LECTURA_CRITICA  PERCENTIL_LECTURA_CRITICA  \
# FAMI_TIENESERVICIOTV
# No                               50.067610                  44.390588
# Si                               53.153235                  52.793697
# NaN                              47.989257                  39.238325
#
#                       DESEMP_LECTURA_CRITICA  PUNT_MATEMATICAS  \
# FAMI_TIENESERVICIOTV
# No                                  2.472946         48.530676
# Si                                  2.678991         51.729178
# NaN                                 2.341686         44.828578
#
#                       PERCENTIL_MATEMATICAS  DESEMP_MATEMATICAS  \
# FAMI_TIENESERVICIOTV
# No                                45.160736            2.320854
# Si                                52.760959            2.506406
# NaN                               36.666395            2.095530
#
#                       PUNT_C_NATURALES  PERCENTIL_C_NATURALES  \
# FAMI_TIENESERVICIOTV
# ...

# %% [markdown]
# ## Manejo de variables categoricas
#
# ### Ordenar una variable ordinal

# %%
tablaEsc = datos.groupby("FAMI_EDUCACIONMADRE").size()

# %%
tablaEsc ### Es más que una lista, pero menos que un dataframe
### pd.Serie (lista con nombres)
# Out:
# FAMI_EDUCACIONMADRE
# Educación profesional completa           54474
# Educación profesional incompleta         12384
# Ninguno                                  12762
# No Aplica                                 1081
# No sabe                                   9275
# Postgrado                                10805
# Primaria completa                        53441
# Primaria incompleta                      80062
# Secundaria (Bachillerato) completa      136286
# Secundaria (Bachillerato) incompleta     76353
# Técnica o tecnológica completa           52949
# Técnica o tecnológica incompleta         15973
# dtype: int64

# %%
tablaEsc[-1]
# Out:
# 15973

# %%
## tablaEsc = tablaEsc.reset_index(name="conteo")
tablaEsc = datos.groupby("FAMI_EDUCACIONMADRE", as_index=False).size()

# %%
tablaEsc
# Out:
#                      FAMI_EDUCACIONMADRE    size
# 0         Educación profesional completa   54474
# 1       Educación profesional incompleta   12384
# 2                                Ninguno   12762
# 3                              No Aplica    1081
# 4                                No sabe    9275
# 5                              Postgrado   10805
# 6                      Primaria completa   53441
# 7                    Primaria incompleta   80062
# 8     Secundaria (Bachillerato) completa  136286
# 9   Secundaria (Bachillerato) incompleta   76353
# 10        Técnica o tecnológica completa   52949
# 11      Técnica o tecnológica incompleta   15973

# %%
tablaEsc = datos.groupby("FAMI_EDUCACIONMADRE", as_index=False).size()
tablaEsc
# Out:
#                      FAMI_EDUCACIONMADRE    size
# 0         Educación profesional completa   54474
# 1       Educación profesional incompleta   12384
# 2                                Ninguno   12762
# 3                              No Aplica    1081
# 4                                No sabe    9275
# 5                              Postgrado   10805
# 6                      Primaria completa   53441
# 7                    Primaria incompleta   80062
# 8     Secundaria (Bachillerato) completa  136286
# 9   Secundaria (Bachillerato) incompleta   76353
# 10        Técnica o tecnológica completa   52949
# 11      Técnica o tecnológica incompleta   15973

# %%
tablaEsc['FAMI_EDUCACIONMADRE']
# Out:
# 0           Educación profesional completa
# 1         Educación profesional incompleta
# 2                                  Ninguno
# 3                                No Aplica
# 4                                  No sabe
# 5                                Postgrado
# 6                        Primaria completa
# 7                      Primaria incompleta
# 8       Secundaria (Bachillerato) completa
# 9     Secundaria (Bachillerato) incompleta
# 10          Técnica o tecnológica completa
# 11        Técnica o tecnológica incompleta
# Name: FAMI_EDUCACIONMADRE, dtype: object

# %% [markdown]
# ### Organizar la variable
#
# 1. Opción 1

# %%
datos["FAMI_EDUCACIONMADRE"] = pd.Categorical(datos["FAMI_EDUCACIONMADRE"],
                                              categories=["Ninguno", "Primaria incompleta","Primaria completa",
                                                          "Secundaria (Bachillerato) incompleta", "Secundaria (Bachillerato) completa",
                                                          "Técnica o tecnológica incompleta","Técnica o tecnológica completa",
                                                          "Educación profesional incompleta", "Educación profesional completa",
                                                          "Postgrado", "No Aplica", "No sabe"],
                                               ordered=True)
datos.groupby('FAMI_EDUCACIONMADRE').size()
# Out:
# FAMI_EDUCACIONMADRE
# Ninguno                                  12762
# Primaria incompleta                      80062
# Primaria completa                        53441
# Secundaria (Bachillerato) incompleta     76353
# Secundaria (Bachillerato) completa      136286
# Técnica o tecnológica incompleta         15973
# Técnica o tecnológica completa           52949
# Educación profesional incompleta         12384
# Educación profesional completa           54474
# Postgrado                                10805
# No Aplica                                 1081
# No sabe                                   9275
# dtype: int64

# %% [markdown]
# Opción 2
# 1. Reemplazar Ninguno ---> 01. Ninguno
# 2. Primaria incompleta ---> 02. Primaria Incompleta

# %%
tablaEsc = datos.groupby('FAMI_EDUCACIONMADRE', as_index=False).size()
fig= px.bar(tablaEsc, x="FAMI_EDUCACIONMADRE", y="size")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Más opciones en Plotly
#
# [Acá](https://plotly.com/python/)

# %%
fig= px.bar(tablaEsc, x="FAMI_EDUCACIONMADRE", y="size",
            labels=dict(FAMI_EDUCACIONMADRE="Nivel educativo máximo de la madre", size="Número de estudiantes"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Y la relativa?
#
# ¿Cómo calculamos porcentajes?

# %%
total = sum(tablaEsc["size"])
tablaEsc["Relativa"] = 100*tablaEsc["size"]/total
tablaEsc
# Out:
#                      FAMI_EDUCACIONMADRE    size   Relativa
# 0                                Ninguno   12762   2.473999
# 1                    Primaria incompleta   80062  15.520554
# 2                      Primaria completa   53441  10.359895
# 3   Secundaria (Bachillerato) incompleta   76353  14.801539
# 4     Secundaria (Bachillerato) completa  136286  26.419952
# 5       Técnica o tecnológica incompleta   15973   3.096473
# 6         Técnica o tecnológica completa   52949  10.264517
# 7       Educación profesional incompleta   12384   2.400721
# 8         Educación profesional completa   54474  10.560149
# 9                              Postgrado   10805   2.094621
# 10                             No Aplica    1081   0.209559
# 11                               No sabe    9275   1.798021

# %%
fig= px.bar(tablaEsc, x="FAMI_EDUCACIONMADRE", y="Relativa",
            labels=dict(FAMI_EDUCACIONMADRE="Nivel educativo máximo de la madre", Relativa="Porcentaje de estudiantes"))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Tarea para el 23 de febrero (grupos de 2 a 4 personas)
#
# 1. Convertir la fecha de nacimiento a datetime.
# 2. Calcular la edad de cada estudiante en días.
# 3. Construir el gráfico de barras de la variable Estrato de la vivienda, tanto con porcentajes como con conteos.
# 4. Hacer el gráfico de pastel con la misma variable anterior.
# 5. Hacer el boxplot del puntaje de matematicas en función del departamento. ¿Cómo le parece esta gráfica?.
# 6. Cómo graficarian la edad del estudiante.

# %% [markdown]
# ## Comentarios adicionales
#
# Agrupar las PUNT_MATEMATICAS por el sexo, contar la cantidad de ocurrencias.

# %%
tabla = datos.groupby(by=["PUNT_MATEMATICAS", "ESTU_GENERO"], as_index=False).size()
### Mandar el genero a columnas
### Pivot_longer and pivot_wider

# %%
tabla_pivote = tabla.pivot(index="PUNT_MATEMATICAS", columns="ESTU_GENERO", values="size")
tabla_pivote
# Out:
# ESTU_GENERO         F    M
# PUNT_MATEMATICAS
# 0                   6    4
# 15                  7    4
# 16                  7   10
# 17                 38   31
# 18                102   42
# ...               ...  ...
# 82                141  249
# 83                119  266
# 84                 26   63
# 85                  4    5
# 100               149  377
#
# [73 rows x 2 columns]

# %%
### Opción reset_index
tabla_pivote1 = tabla_pivote.reset_index()
tabla_pivote1
# Out:
# ESTU_GENERO  PUNT_MATEMATICAS    F    M
# 0                           0    6    4
# 1                          15    7    4
# 2                          16    7   10
# 3                          17   38   31
# 4                          18  102   42
# ..                        ...  ...  ...
# 68                         82  141  249
# 69                         83  119  266
# 70                         84   26   63
# 71                         85    4    5
# 72                        100  149  377
#
# [73 rows x 3 columns]

# %% [markdown]
# ## Fechas
#
# Para mayor información [consulte acá](https://docs.python.org/3/library/datetime.html)

# %%
datos["Fecha"] = pd.to_datetime(datos["ESTU_FECHANACIMIENTO"], format="%m/%d/%Y %H:%M:%S %p", errors ="coerce")

# %%
limites = [0,25,50,75,100]
datos["PUNT_MAT"]= pd.cut(datos["PUNT_MATEMATICAS"], bins=limites, labels=["A","B", "C","D"])
datos["PUNT_MAT"]
datos.groupby(by="PUNT_MAT").size()
# Out:
# PUNT_MAT
# A      7153
# B    263171
# C    267243
# D      8635
# dtype: int64

# %%
datos.groupby("PUNT_MATEMATICAS").size()
# Out:
# PUNT_MATEMATICAS
# 0       10
# 15      11
# 16      17
# 17      69
# 18     144
#       ...
# 82     390
# 83     385
# 84      89
# 85       9
# 100    526
# Length: 73, dtype: int64
